# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# ## 1

# %% [markdown]
# (a) data의 양이 많고 변수가 적기 때문에, flexible한 모델이 좋다.

# %% [markdown]
# (b) data의 양이 적고 변수가 많기 때문에, inflexible한 모델이 좋다.

# %% [markdown]
# (c) non-linear 모델, 즉 inflexible한 모델이 좋다.

# %% [markdown]
# (d) inflexible한 모델이 좋다.

# %% [markdown]
# ## 8

# %% [markdown]
# (a)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
college = pd.read_csv('college.csv')

# %%
college
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %% [markdown]
# (b)

# %%
del college['Unnamed: 0']

# %%
college
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# 5       Yes    587     479     158         38         62          678
# 6       Yes    353     340     103         17         45          416
# 7       Yes   1899    1720     489         37         68         1594
# 8       Yes   1038     839     227         30         63          973
# 9       Yes    582     498     172         21         44          799
# 10      Yes   1732    1425     472         37         75         1830
# 11      Yes   2652    1900     484         44         77         1707
# ...

# %% [markdown]
# (c)

# %%
college.describe(include = 'all')
# Out:
#        Private          Apps        Accept       Enroll   Top10perc  \
# count      777    777.000000    777.000000   777.000000  777.000000
# unique       2           NaN           NaN          NaN         NaN
# top        Yes           NaN           NaN          NaN         NaN
# freq       565           NaN           NaN          NaN         NaN
# mean       NaN   3001.638353   2018.804376   779.972973   27.558559
# std        NaN   3870.201484   2451.113971   929.176190   17.640364
# min        NaN     81.000000     72.000000    35.000000    1.000000
# 25%        NaN    776.000000    604.000000   242.000000   15.000000
# 50%        NaN   1558.000000   1110.000000   434.000000   23.000000
# 75%        NaN   3624.000000   2424.000000   902.000000   35.000000
# max        NaN  48094.000000  26330.000000  6392.000000   96.000000
#
#          Top25perc   F.Undergrad   P.Undergrad      Outstate   Room.Board  \
# count   777.000000    777.000000    777.000000    777.000000   777.000000
# ...

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='object')

# %%
plt.scatter(college['Apps'], college['Accept'])
plt.xlabel('Apps')
plt.ylabel('Accept')
plt.title('Apps vs Accept')
plt.show()

# %%
sns.pairplot(college.iloc[:, 1:11])

# %%
sns.boxplot(x = 'Private', y = 'Outstate', data = college)

# %%
college['Elite'] = college['Top10perc'] > 50

# %%
college.groupby('Elite').count()
# Out:
#        Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# Elite
# False      699   699     699     699        699        699          699
# True        78    78      78      78         78         78           78
#
#        P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# Elite
# False          699       699         699    699       699  699       699
# True            78        78          78     78        78   78        78
#
#        S.F.Ratio  perc.alumni  Expend  Grad.Rate
# Elite
# False        699          699     699        699
# True          78           78      78         78

# %%
sns.boxplot(x = 'Elite', y = 'Outstate', data = college)

# %%
college[['Apps', 'Enroll', 'Expend', 'Outstate']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D8324C0BA8>,
# ...
#       dtype=object)

# %% [markdown]
# ## 9

# %%
auto = pd.read_csv('auto.csv')

# %%
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# 5    15.0          8         429.0        198    4341          10.0    70
# 6    14.0          8         454.0        220    4354           9.0    70
# 7    14.0          8         440.0        215    4312           8.5    70
# 8    14.0          8         455.0        225    4425          10.0    70
# 9    15.0          8         390.0        190    3850           8.5    70
# 10   15.0          8         383.0        170    3563          10.0    70
# 11   14.0          8         340.0        160    3609           8.0    70
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
# mpg             397 non-null float64
# cylinders       397 non-null int64
# displacement    397 non-null float64
# horsepower      397 non-null object
# weight          397 non-null int64
# acceleration    397 non-null float64
# year            397 non-null int64
# origin          397 non-null int64
# name            397 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
remain = pd.concat([auto.iloc[1:10], auto.iloc[86:]])

# %%
remain
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# 5    15.0          8         429.0        198    4341          10.0    70
# 6    14.0          8         454.0        220    4354           9.0    70
# 7    14.0          8         440.0        215    4312           8.5    70
# 8    14.0          8         455.0        225    4425          10.0    70
# 9    15.0          8         390.0        190    3850           8.5    70
# 86   14.0          8         304.0        150    3672          11.5    73
# 87   13.0          8         350.0        145    3988          13.0    73
# 88   14.0          8         302.0        137    4042          14.5    73
# ...

# %%
remain.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  320.000000  320.000000    320.000000   320.000000    320.000000
# mean    24.465000    5.362500    186.800000  2931.400000     15.720625
# std      7.904042    1.649499     99.795012   810.274671      2.702689
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000     99.500000  2213.750000     14.000000
# 50%     23.950000    4.000000    144.500000  2792.500000     15.550000
# 75%     30.750000    6.000000    250.000000  3478.750000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  320.000000  320.000000
# mean    77.165625    1.600000
# std      3.107389    0.816752
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
sns.pairplot(auto.iloc[:, 0:7])

# %% [markdown]
# ## 10

# %%
boston = pd.read_csv('boston.csv')

# %%
boston
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
boston.shape
# Out:
# (506, 14)

# %%
sns.pairplot(boston, x_vars = ['zn', 'indus', 'age', 'dis', 'rad', 'tax', 'medv'], y_vars = ['crim'])

# %%
sns.pairplot(boston, x_vars = ['nox', 'rm', 'ptratio', 'black', 'lstat'], y_vars = ['crim'])

# %%
boston['crim'].hist()

# %%
boston['tax'].hist()

# %%
boston['ptratio'].hist()

# %%
boston[boston['crim'] > 30]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
#
#      ptratio   black  lstat  medv
# 380     20.2  396.90  17.21  10.4
# 398     20.2  396.90  30.59   5.0
# 404     20.2  329.46  27.38   8.5
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0
# 418     20.2   16.45  20.62   8.8
# 427     20.2   18.82  14.52  10.9

# %%
boston['chas'].value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
boston['ptratio'].median()
# Out:
# 19.05

# %%
boston.sort_values('medv').head()
# Out:
#          crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.35180  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.92080  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 400  25.04610  0.0   18.1     0  0.693  5.987  100.0  1.5888   24  666
# 399   9.91655  0.0   18.1     0  0.693  5.852   77.8  1.5004   24  666
# 414  45.74610  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
#
#      ptratio   black  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0
# 400     20.2  396.90  26.77   5.6
# 399     20.2  338.16  29.97   6.3
# 414     20.2   88.27  36.98   7.0

# %%
boston['crim'].hist()

# %%
boston[boston['rm'] > 7].shape
# Out:
# (64, 14)

# %%
boston[boston['rm'] > 8].shape
# Out:
# (13, 14)
